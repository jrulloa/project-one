# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress

# %% [markdown]
# ###Population

# %%
population_filepath = "Resources/Population.csv"
income_filepath = "Resources/personal_income (USD).csv"
gdp_filepath = "Resources/GDP_USD.csv"
expenditure_filepath = "Resources/spending_per_category_by_year.csv"
gas_filepath = "Resources/gas.csv"

# %%
population_df = pd.read_csv(population_filepath)
# population_df.head()
population_clean = population_df[['GeoName', '2015', '2016', '2017', '2018', '2019']]
# population_clean

# %%
#Cleaning the Population Clean
population_cleaner = population_clean.dropna(how='any')
# population_cleaner

# %%
states_df = population_cleaner.iloc[1:52]
# states_df

# %%
final_pop_df = states_df.rename(columns={"GeoName": "States"})
# final_pop_df

# %% [markdown]
# ###Income Data

# %%
income_df = pd.read_csv(income_filepath)
# income_df.head()

# %%
income_clean = income_df[['GeoName', '2015', '2016', '2017', '2018', '2019']]
# income_clean
income_cleaner = income_clean.dropna(how='any')
# income_cleaner
states_income_df = income_cleaner.iloc[1:52]
# states_income_df
final_inc_df = states_income_df.rename(columns={"GeoName": "States"})
# final_inc_df

# %% [markdown]
# ###GDP

# %%
gdp_df = pd.read_csv(gdp_filepath)
# gdp_df.head()

# %%
gdp_clean =gdp_df[['GeoName', '2015', '2016', '2017', '2018', '2019']]
# income_clean
gdp_cleaner = gdp_clean.dropna(how='any')
# income_cleaner
states_gdp_df = gdp_cleaner.iloc[1:52]
# states_income_df
final_gdp_df = states_gdp_df.rename(columns={"GeoName": "States"})
# final_gdp_df

# %%
final_pop_df["States_Pop_Average"]=final_pop_df.mean(axis=1)
final_pop_df
# Out:
#                   States        2015        2016        2017        2018  \
# 1                Alabama   4852347.0   4863525.0   4874486.0   4887681.0
# 2                 Alaska    737498.0    741456.0    739700.0    735139.0
# 3                Arizona   6829676.0   6941072.0   7044008.0   7158024.0
# 4               Arkansas   2978048.0   2989918.0   3001345.0   3009733.0
# 5             California  38918045.0  39167117.0  39358497.0  39461588.0
# 6               Colorado   5450623.0   5539215.0   5611885.0   5691287.0
# 7            Connecticut   3587122.0   3578141.0   3573297.0   3571520.0
# 8               Delaware    941252.0    948921.0    956823.0    965479.0
# 9   District of Columbia    675400.0    685815.0    694906.0    701547.0
# 10               Florida  20209042.0  20613477.0  20963613.0  21244317.0
# 11               Georgia  10178447.0  10301890.0  10410330.0  10511131.0
# 12                Hawaii   1422052.0   1427559.0   1424393.0   1420593.0
# ...

# %%
final_inc_df["States_Inc_Average"]=final_inc_df.mean(axis=1)
final_inc_df
# Out:
#                   States       2015       2016       2017       2018  \
# 1                Alabama   188711.4   192281.9   199999.8   208752.7
# 2                 Alaska    42505.8    41745.6    42454.4    44369.6
# 3                Arizona   271258.0   283199.3   300007.5   319226.3
# 4               Arkansas   117671.8   120748.2   125025.7   130397.5
# 5             California  2172930.2  2273557.5  2383130.5  2514503.4
# 6               Colorado   284819.6   290669.6   312045.5   335195.8
# 7            Connecticut   245244.0   250178.6   256348.8   267346.2
# 8               Delaware    45196.4    46341.8    48604.3    51103.1
# 9   District of Columbia    50963.6    53375.8    55051.1    56995.8
# 10               Florida   914928.4   949718.0  1016819.0  1082702.2
# 11               Georgia   425498.4   441905.5   467359.4   493575.9
# 12                Hawaii    70376.2    73048.0    76109.6    78436.1
# 13                 Idaho    65683.4    68248.4    72605.0    77992.6
# ...

# %%
final_gdp_df["States_GDP_Average"]=final_gdp_df.mean(axis=1)
final_gdp_df
# Out:
#                   States       2015       2016       2017       2018  \
# 1                Alabama   200197.5   204454.7   210895.7   221030.7
# 2                 Alaska    50728.1    49755.6    51737.0    54292.9
# 3                Arizona   298615.0   313056.5   330146.6   350718.3
# 4               Arkansas   117734.3   119191.8   122978.5   127761.3
# 5             California  2559643.2  2671100.5  2831038.4  2975083.0
# 6               Colorado   317992.4   327757.3   348175.5   372452.9
# 7            Connecticut   262372.7   266747.3   272569.9   279782.3
# 8               Delaware    71547.8    69284.2    69899.4    74186.7
# 9   District of Columbia   124853.7   129477.1   132853.6   138773.5
# 10               Florida   897754.7   941561.2   990096.6  1050298.4
# 11               Georgia   515753.0   541292.2   568398.9   602023.9
# 12                Hawaii    82644.0    85899.9    89618.6    93100.5
# 13                 Idaho    66082.0    69075.5    73286.5    79090.8
# ...

# %% [markdown]
# ###Merging datasets

# %%
merge_pop_inc_df = pd.merge(final_pop_df, final_inc_df, how="left", on="States")
merge_pop_inc_df
# Out:
#                   States      2015_x      2016_x      2017_x      2018_x  \
# 0                Alabama   4852347.0   4863525.0   4874486.0   4887681.0
# 1                 Alaska    737498.0    741456.0    739700.0    735139.0
# 2                Arizona   6829676.0   6941072.0   7044008.0   7158024.0
# 3               Arkansas   2978048.0   2989918.0   3001345.0   3009733.0
# 4             California  38918045.0  39167117.0  39358497.0  39461588.0
# 5               Colorado   5450623.0   5539215.0   5611885.0   5691287.0
# 6            Connecticut   3587122.0   3578141.0   3573297.0   3571520.0
# 7               Delaware    941252.0    948921.0    956823.0    965479.0
# 8   District of Columbia    675400.0    685815.0    694906.0    701547.0
# 9                Florida  20209042.0  20613477.0  20963613.0  21244317.0
# 10               Georgia  10178447.0  10301890.0  10410330.0  10511131.0
# 11                Hawaii   1422052.0   1427559.0   1424393.0   1420593.0
# ...

# %%
merge_pop_inc_gdp_df = pd.merge(merge_pop_inc_df, final_gdp_df, how="left", on="States")
merge_pop_inc_gdp_df
# Out:
#                   States      2015_x      2016_x      2017_x      2018_x  \
# 0                Alabama   4852347.0   4863525.0   4874486.0   4887681.0
# 1                 Alaska    737498.0    741456.0    739700.0    735139.0
# 2                Arizona   6829676.0   6941072.0   7044008.0   7158024.0
# 3               Arkansas   2978048.0   2989918.0   3001345.0   3009733.0
# 4             California  38918045.0  39167117.0  39358497.0  39461588.0
# 5               Colorado   5450623.0   5539215.0   5611885.0   5691287.0
# 6            Connecticut   3587122.0   3578141.0   3573297.0   3571520.0
# 7               Delaware    941252.0    948921.0    956823.0    965479.0
# 8   District of Columbia    675400.0    685815.0    694906.0    701547.0
# 9                Florida  20209042.0  20613477.0  20963613.0  21244317.0
# 10               Georgia  10178447.0  10301890.0  10410330.0  10511131.0
# 11                Hawaii   1422052.0   1427559.0   1424393.0   1420593.0
# ...

# %%
merge_pop_inc_gdp_df.columns
# Out:
# Index(['States', '2015_x', '2016_x', '2017_x', '2018_x', '2019_x',
#        'States_Pop_Average', '2015_y', '2016_y', '2017_y', '2018_y', '2019_y',
#        'States_Inc_Average', '2015', '2016', '2017', '2018', '2019',
#        'States_GDP_Average'],
#       dtype='object')

# %%
merge_pop_inc_gdp_df = merge_pop_inc_gdp_df.rename(columns={'2015_x':'2015_Pop', '2016_x':
                                                            '2016_Pop', '2017_x':'2017_Pop', '2018_x':'2018_Pop',
                                                            '2019_x':'2019_Pop',
                                                            '2015_y': '2015_Inc', 
                                                            '2016_y': '2016_Inc', '2017_y': '2017_Inc', '2018_y': '2018_Inc',
                                                            '2019_y': '2019_Inc', 
                                                            '2015': '2015_GDP',
                                                            '2016': '2016_GDP', '2017': '2017_GDP', '2018': '2018_GDP', '2019': '2019_GDP'})
merge_pop_inc_gdp_df
# Out:
#                   States    2015_Pop    2016_Pop    2017_Pop    2018_Pop  \
# 0                Alabama   4852347.0   4863525.0   4874486.0   4887681.0
# 1                 Alaska    737498.0    741456.0    739700.0    735139.0
# 2                Arizona   6829676.0   6941072.0   7044008.0   7158024.0
# 3               Arkansas   2978048.0   2989918.0   3001345.0   3009733.0
# 4             California  38918045.0  39167117.0  39358497.0  39461588.0
# 5               Colorado   5450623.0   5539215.0   5611885.0   5691287.0
# 6            Connecticut   3587122.0   3578141.0   3573297.0   3571520.0
# 7               Delaware    941252.0    948921.0    956823.0    965479.0
# 8   District of Columbia    675400.0    685815.0    694906.0    701547.0
# 9                Florida  20209042.0  20613477.0  20963613.0  21244317.0
# 10               Georgia  10178447.0  10301890.0  10410330.0  10511131.0
# 11                Hawaii   1422052.0   1427559.0   1424393.0   1420593.0
# ...

# %% [markdown]
# ###Calculate average for POP from 2015-2019 per state, for INC from 2015-2019 per state, for GDP from 2015-2019 per state
#
# ###Use average per state to calculate the Income and GDP per capita

# %%
per_capita = merge_pop_inc_gdp_df[["States","States_Pop_Average", "States_Inc_Average", "States_GDP_Average"]]
per_capita


per_capita['per_capita_inc'] = (per_capita['States_Inc_Average']/per_capita['States_Pop_Average'])*1000000
per_capita['per_capita_gdp'] = (per_capita['States_GDP_Average']/per_capita['States_Pop_Average'])*1000000
per_capita
# Out:
# c:\users\ulloa\.conda\envs\pythodata\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# c:\users\ulloa\.conda\envs\pythodata\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                   States  States_Pop_Average  States_Inc_Average  \
# 0                Alabama           4876244.8           201238.96
# 1                 Alaska            737067.6            43404.10
# ...

# %% [markdown]
# ###Grab top 5 and lowest 5 states for per capita GDP and per capita income

# %%
sorted_inc = per_capita.sort_values("per_capita_inc", ascending=True)
sorted_inc= sorted_inc[["States", "per_capita_inc"]]

sorted_inc= sorted_inc.reset_index(drop=True)
sorted_inc
# Out:
#                   States  per_capita_inc
# 0            Mississippi    36833.926995
# 1          West Virginia    39298.223796
# 2             New Mexico    40419.631486
# 3               Kentucky    41198.566777
# 4                Alabama    41269.248829
# 5               Arkansas    41910.533467
# 6         South Carolina    42357.518175
# 7                  Idaho    42692.776776
# 8                Arizona    42804.826133
# 9              Louisiana    44601.548242
# 10              Oklahoma    44616.982822
# 11        North Carolina    44642.910932
# 12                  Utah    44754.396612
# 13               Georgia    44992.544198
# 14             Tennessee    45504.042951
# 15               Indiana    45527.590184
# 16              Missouri    45723.015164
# 17              Michigan    46217.749656
# 18               Montana    46387.832772
# 19                 Maine    46899.659451
# 20                  Ohio    47085.868611
# 21                Nevada    47761.659610
# ...

# %%
bottom_inc = sorted_inc.iloc[0:5]
bottom_inc
# Out:
#           States  per_capita_inc
# 0    Mississippi    36833.926995
# 1  West Virginia    39298.223796
# 2     New Mexico    40419.631486
# 3       Kentucky    41198.566777
# 4        Alabama    41269.248829

# %%
top_inc = sorted_inc.iloc[46:]
top_inc
# Out:
#                   States  per_capita_inc
# 46              New York    65349.666649
# 47            New Jersey    65460.955175
# 48         Massachusetts    68774.878103
# 49           Connecticut    72427.850013
# 50  District of Columbia    79473.623881

# %%
sorted_gdp = per_capita.sort_values("per_capita_gdp", ascending=True)
sorted_gdp= sorted_gdp[["States", "per_capita_gdp"]]

sorted_gdp= sorted_gdp.reset_index(drop=True)
sorted_gdp
# Out:
#                   States  per_capita_gdp
# 0            Mississippi    36918.539818
# 1          West Virginia    40738.566986
# 2               Arkansas    41250.001334
# 3                  Idaho    43219.337378
# 4                Alabama    43669.718961
# 5         South Carolina    44766.878994
# 6               Kentucky    45504.240635
# 7             New Mexico    46093.435701
# 8                Montana    46356.633092
# 9                  Maine    46613.472788
# 10               Arizona    47165.528885
# 11               Florida    47711.200346
# 12              Oklahoma    48212.666850
# 13              Missouri    50566.186184
# 14              Michigan    50630.234068
# 15             Louisiana    51498.072169
# 16               Vermont    51618.099132
# 17             Tennessee    51978.058463
# 18               Indiana    52966.342340
# 19        North Carolina    53059.755283
# 20                Nevada    53810.272224
# 21                  Utah    54772.794012
# ...

# %%
merge_per_inc_gdp = pd.merge(sorted_inc, sorted_gdp, how="left", on="States")
merge_per_inc_gdp
# Out:
#                   States  per_capita_inc  per_capita_gdp
# 0            Mississippi    36833.926995    36918.539818
# 1          West Virginia    39298.223796    40738.566986
# 2             New Mexico    40419.631486    46093.435701
# 3               Kentucky    41198.566777    45504.240635
# 4                Alabama    41269.248829    43669.718961
# 5               Arkansas    41910.533467    41250.001334
# 6         South Carolina    42357.518175    44766.878994
# 7                  Idaho    42692.776776    43219.337378
# 8                Arizona    42804.826133    47165.528885
# 9              Louisiana    44601.548242    51498.072169
# 10              Oklahoma    44616.982822    48212.666850
# 11        North Carolina    44642.910932    53059.755283
# 12                  Utah    44754.396612    54772.794012
# 13               Georgia    44992.544198    54848.602981
# 14             Tennessee    45504.042951    51978.058463
# ...

# %%
bottom_gdp = sorted_gdp.iloc[0:5]
bottom_gdp
# Out:
#           States  per_capita_gdp
# 0    Mississippi    36918.539818
# 1  West Virginia    40738.566986
# 2       Arkansas    41250.001334
# 3          Idaho    43219.337378
# 4        Alabama    43669.718961

# %%
top_gdp = sorted_gdp.iloc[46:]
top_gdp
# Out:
#                   States  per_capita_gdp
# 46              Delaware    75633.602919
# 47           Connecticut    76602.309760
# 48         Massachusetts    79682.701801
# 49              New York    82951.550199
# 50  District of Columbia   193262.087701

# %%
expenditure_df = pd.read_csv(expenditure_filepath)
expenditure_df= expenditure_df.sort_values('Year', ascending=True)
expenditure_df.head(100)
# Out:
#             State  Year      Durable goods      Nondurable goods    Services
# 0         Alabama  2015            17271.7               39144.7     94382.0
# 28         Nevada  2015            12345.4               23857.5     74789.7
# 29  New Hampshire  2015             6260.4               13445.3     43811.1
# 30     New Jersey  2015            40916.2               81969.3    297597.5
# 31     New Mexico  2015             7907.0               15271.5     45897.8
# ..            ...   ...                ...                   ...         ...
# 70          Maine  2016             6035.4               13524.7     36755.8
# 74      Minnesota  2016            27381.3               42552.2    164083.4
# 68       Kentucky  2016            15828.2               37024.7     93610.9
# 67         Kansas  2016            11485.2               23330.9     68654.3
# 66           Iowa  2016            13547.5               25667.9     74043.9
#
# [100 rows x 5 columns]

# %% [markdown]
# ###Adding other csv file from other notebooks to the mix (states)

# %%
states_filepath = "Resources/states.csv"
states_df = pd.read_csv(states_filepath)
states_df = states_df.rename(columns= {'State':'State_1'})
states_df = states_df.rename(columns= {'State Name':'State'})
states_df
# Out:
#                    State State_1
# 0                Alabama      AL
# 1                 Alaska      AK
# 2                Arizona      AZ
# 3               Arkansas      AR
# 4             California      CA
# 5               Colorado      CO
# 6            Connecticut      CT
# 7               Delaware      DE
# 8                Florida      FL
# 9                Georgia      GA
# 10                Hawaii      HI
# 11                 Idaho      ID
# 12              Illinois      IL
# 13               Indiana      IN
# 14                  Iowa      IA
# 15                Kansas      KS
# 16              Kentucky      KY
# 17             Louisiana      LA
# 18                 Maine      ME
# 19              Maryland      MD
# 20         Massachusetts      MA
# 21              Michigan      MI
# 22             Minnesota      MN
# 23           Mississippi      MS
# 24              Missouri      MO
# 25               Montana      MT
# 26              Nebraska      NE
# ...

# %%
merge_pru = pd.merge(expenditure_df, states_df, how="left", on="State")
merge_pru
# Out:
#              State  Year      Durable goods      Nondurable goods    Services  \
# 0          Alabama  2015            17271.7               39144.7     94382.0
# 1           Nevada  2015            12345.4               23857.5     74789.7
# 2    New Hampshire  2015             6260.4               13445.3     43811.1
# 3       New Jersey  2015            40916.2               81969.3    297597.5
# 4       New Mexico  2015             7907.0               15271.5     45897.8
# ..             ...   ...                ...                   ...         ...
# 250       Maryland  2019            27355.1               53608.5    206380.2
# 251  Massachusetts  2019            38557.9               71922.6    277089.8
# 252       Michigan  2019            44480.9               88539.2    284594.7
# 253    Mississippi  2019            10602.7               23872.4     61741.6
# 254        Wyoming  2019             2433.4                5446.4     17425.1
#
#     State_1
# 0        AL
# ...

# %% [markdown]
# ###Adding other csv file from other notebooks to the mix (gast costs)

# %%
#Getting gas Cost
gas_cost_df = pd.read_csv(gas_filepath)
gas_cost_df = gas_cost_df[['Year','Price per gallon','State Name']]
gas_cost_df = gas_cost_df.rename(columns= {'State Name':'State'})
gas_cost_df = gas_cost_df.sort_values('Year', ascending=True)
gas_cost_df
# Out:
#      Year  Price per gallon                 State
# 254  2015          2.475039  District of Columbia
# 219  2015          2.418155                  Utah
# 34   2015          2.410028           Connecticut
# 214  2015          2.120964                 Texas
# 154  2015          2.202227            New Mexico
# ..    ...               ...                   ...
# 180  2019          3.110051                Oregon
# 75   2019          2.345018                Kansas
# 175  2019          2.297421              Oklahoma
# 215  2019          2.668909                  Utah
# 0    2019          2.202227               Alabama
#
# [255 rows x 3 columns]

# %% [markdown]
# ###Merging Expenditures and gas cost

# %%
gas_cost_Expend_df = pd.merge(expenditure_df,gas_cost_df, how="left", on= ["State" , "Year"] )
gas_cost_Expend_df

#PriceGas= gas_cost_Expend_df.iloc[:,2]
#PriceGas
# Out:
#              State  Year      Durable goods      Nondurable goods    Services  \
# 0          Alabama  2015            17271.7               39144.7     94382.0
# 1           Nevada  2015            12345.4               23857.5     74789.7
# 2    New Hampshire  2015             6260.4               13445.3     43811.1
# 3       New Jersey  2015            40916.2               81969.3    297597.5
# 4       New Mexico  2015             7907.0               15271.5     45897.8
# ..             ...   ...                ...                   ...         ...
# 250       Maryland  2019            27355.1               53608.5    206380.2
# 251  Massachusetts  2019            38557.9               71922.6    277089.8
# 252       Michigan  2019            44480.9               88539.2    284594.7
# 253    Mississippi  2019            10602.7               23872.4     61741.6
# 254        Wyoming  2019             2433.4                5446.4     17425.1
#
#      Price per gallon
# ...

# %% [markdown]
# ###Plotting Data gas price vs. durable goods

# %%
x = gas_cost_Expend_df['Price per gallon'] # Gasoline Price 
y_dg = gas_cost_Expend_df.iloc[:,2] #Durable Goods
y_ndg = gas_cost_Expend_df.iloc[:,3] #NO Durable Goods
y_s = gas_cost_Expend_df.iloc[:,4] # Services

fignum = 1

#Linear Regression Durable Goods
(slope, intercept, rvalue, pvalue, stderr) = linregress(x,y_dg)
r2 =(f"The r-squared is: {round(rvalue**2,4)}")
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The slope of the line is:{round(slope,3)}")
print(f"The y-intercept is:{round(intercept,3)}")
print(f"The rvalue (Correlation coefficient) is:{round(rvalue,3)}")
print(f"The pvalue is:{round(pvalue,3)}")
print(f"The standard error is:{round(stderr,3)}")

plt.scatter(x,y_dg, marker="o", facecolors="green", edgecolors="black",s=30, alpha=0.75)
plt.title("Durable Goods")
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(2.7,140000),fontsize=12,color="red")
plt.annotate(r2,(2.7,125000),fontsize=10,color="black")

plt.savefig(f"output_data/fig{fignum}.png")
fignum = fignum + 1
# Out:
# The slope of the line is:4484.04
# The y-intercept is:17007.261
# The rvalue (Correlation coefficient) is:0.043
# The pvalue is:0.491
# The standard error is:6496.687

# %% [markdown]
# ###Plotting Data gas price vs. non-durable goods

# %%
#Linear Regression Non-Durable Goods
(slope, intercept, rvalue, pvalue, stderr) = linregress(x,y_ndg)
r2=(f"The r-squared is: {round(rvalue**2,4)}")
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The slope of the line is:{round(slope,3)}")
print(f"The y-intercept is:{round(intercept,3)}")
print(f"The rvalue (Correlation coefficient) is:{round(rvalue,3)}")
print(f"The pvalue is:{round(pvalue,3)}")
print(f"The standard error is:{round(stderr,3)}")

plt.scatter(x,y_ndg, marker="s", facecolors="brown", edgecolors="black",s=30, alpha=0.75)
plt.title("Non Durable Goods")
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(2.7,250000),fontsize=12,color="red")
plt.annotate(r2,(2.7,225000),fontsize=10,color="black")

plt.savefig(f"output_data/fig{fignum}.png")
fignum = fignum + 1
# Out:
# The slope of the line is:4817.264
# The y-intercept is:42739.134
# The rvalue (Correlation coefficient) is:0.024
# The pvalue is:0.699
# The standard error is:12436.535

# %% [markdown]
# ###Plotting Data gas price vs. service

# %%
#Linear Regression Services
(slope, intercept, rvalue, pvalue, stderr) = linregress(x,y_s)
r2 = (f"The r-squared is: {round(rvalue**2,4)}")
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The slope of the line is:{round(slope,3)}")
print(fa"The y-intercept is:{round(intercept,3)}")
print(f"The rvalue (Correlation coefficient) is:{round(rvalue,3)}")
print(f"The pvalue is:{round(pvalue,3)}")
print(f"The standard error is:{round(stderr,3)}")

plt.scatter(x,y_ndg, marker="*", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.title("Services")
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(2.7,270000),fontsize=12,color="red")
plt.annotate(r2,(2.7,242000),fontsize=10,color="black")

plt.savefig(f"output_data/fig{fignum}.png")
fignum = fignum + 1
# Out:
# The slope of the line is:59045.921
# The y-intercept is:38384.805
# The rvalue (Correlation coefficient) is:0.083
# The pvalue is:0.188
# The standard error is:44693.049

# %% [markdown]
# ##Grabbing top 5 states

# %%
gas_cost_Expend_top5_df = gas_cost_Expend_df.loc[(gas_cost_Expend_df['State'] =='New York') |
                                                    (gas_cost_Expend_df['State'] =='New Jersey') |
                                                    (gas_cost_Expend_df['State'] =='Massachusetts') |
                                                    (gas_cost_Expend_df['State'] =='Connecticut') |
                                                    (gas_cost_Expend_df['State'] =='District of Columbia')]

gas_cost_Expend_top5_df
# Out:
#                     State  Year      Durable goods      Nondurable goods  \
# 3              New Jersey  2015            40916.2               81969.3
# 5                New York  2015            67466.9              181667.9
# 32            Connecticut  2015            15672.1               34849.6
# 34   District of Columbia  2015             2919.6                5889.8
# 47          Massachusetts  2015            33101.5               62894.9
# 58             New Jersey  2016            41458.1               82370.9
# 61               New York  2016            69183.7              183741.6
# 84            Connecticut  2016            15942.9               35011.8
# 86   District of Columbia  2016             3090.7                6115.1
# 93          Massachusetts  2016            34039.2               63772.9
# 105            New Jersey  2017            42311.2               84844.0
# 107              New York  2017            71380.4              191223.0
# ...

# %% [markdown]
# ###Grabbing bottom 5 states

# %%
gas_cost_Expend_botton5_df = gas_cost_Expend_df.loc[(gas_cost_Expend_df['State'] == 'Mississippi') |
                                                    (gas_cost_Expend_df['State'] =='West Virginia') |
                                                    (gas_cost_Expend_df['State'] =='New Mexico') |
                                                    (gas_cost_Expend_df['State'] =='Kentucky') |
                                                    (gas_cost_Expend_df['State'] =='Alabama')]

gas_cost_Expend_botton5_df
# Out:
#              State  Year      Durable goods      Nondurable goods    Services  \
# 0          Alabama  2015            17271.7               39144.7     94382.0
# 4       New Mexico  2015             7907.0               15271.5     45897.8
# 20   West Virginia  2015             6093.3               14952.6     38351.2
# 26     Mississippi  2015             9485.9               22503.5     53525.3
# 43        Kentucky  2015            15157.9               36341.3     89175.7
# 57      New Mexico  2016             7993.2               15166.4     47705.2
# 71   West Virginia  2016             6152.8               15030.1     39818.5
# 77     Mississippi  2016             9820.6               22570.5     55582.0
# 90         Alabama  2016            17924.2               38981.6     98441.8
# 97        Kentucky  2016            15828.2               37024.7     93610.9
# 106     New Mexico  2017             8171.7               15509.8     49203.8
# ...

# %% [markdown]
# ###Plotting Data gas price vs. Durable good (top 5 states)

# %%
x_t5 = gas_cost_Expend_top5_df['Price per gallon'] # Gasoline Price 
y_t5_dg = gas_cost_Expend_top5_df.iloc[:,2] #Durable Goods
y_t5_ndg = gas_cost_Expend_top5_df.iloc[:,3] #NO Durable Goods
y_t5_s = gas_cost_Expend_top5_df.iloc[:,4] # Services



#Linear Regression Durable Goods
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_t5,y_t5_dg)
r2=(f"The r-squared is: {round(rvalue**2,4)}")
regress_values = x_t5 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The slope of the line is:{round(slope,3)}")
print(f"The y-intercept is:{round(intercept,3)}")
print(f"The rvalue (Correlation coefficient) is:{round(rvalue,3)}")
print(f"The pvalue is:{round(pvalue,3)}")
print(f"The standard error is:{round(stderr,3)}")

plt.scatter(x_t5,y_t5_dg, marker="o", facecolors="green", edgecolors="black",s=30, alpha=0.75)
plt.title("TOP 5 Per Capita Income States - Durable Goods")
plt.plot(x_t5,regress_values,"r-")
plt.annotate(line_eq,(2.2,60000),fontsize=12,color="red")
plt.annotate(r2,(2.2,55000),fontsize=10,color="black")

plt.savefig(f"output_data/fig{fignum}.png")
fignum = fignum + 1
# Out:
# The slope of the line is:-33777.903
# The y-intercept is:115856.02
# The rvalue (Correlation coefficient) is:-0.272
# The pvalue is:0.188
# The standard error is:24882.027

# %% [markdown]
# ###Plotting Data gas price vs. Non-Durable good (top 5 states)

# %%
#Linear Regression Non Durable Goods
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_t5,y_t5_ndg)
r2 = (f"The r-squared is: {round(rvalue**2,4)}")
regress_values = x_t5 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The slope of the line is:{round(slope,3)}")
print(f"The y-intercept is:{round(intercept,3)}")
print(f"The rvalue (Correlation coefficient) is:{round(rvalue,3)}")
print(f"The pvalue is:{round(pvalue,3)}")
print(f"The standard error is:{round(stderr,3)}")

plt.scatter(x_t5,y_t5_ndg, marker="s", facecolors="brown", edgecolors="black",s=30, alpha=0.75)
plt.title("TOP 5 Per Capita Income States - Non Durable Goods")
plt.plot(x_t5,regress_values,"r-")
plt.annotate(line_eq,(2.2,120000),fontsize=12,color="red")
plt.annotate(r2,(2.2,105000),fontsize=10,color="black")

plt.savefig(f"output_data/fig{fignum}.png")
fignum = fignum + 1
# Out:
# The slope of the line is:-79688.713
# The y-intercept is:270842.783
# The rvalue (Correlation coefficient) is:-0.237
# The pvalue is:0.255
# The standard error is:68188.531

# %% [markdown]
# ###Plotting Data gas price vs. Services (top 5 states)

# %%
#Linear Regression Services
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_t5,y_t5_s)
r2 =(f"The r-squared is: {round(rvalue**2,4)}")
regress_values = x_t5 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The slope of the line is:{round(slope,3)}")
print(f"The y-intercept is:{round(intercept,3)}")
print(f"The rvalue (Correlation coefficient) is:{round(rvalue,3)}")
print(f"The pvalue is:{round(pvalue,3)}")
print(f"The standard error is:{round(stderr,3)}")


plt.scatter(x_t5,y_t5_s, marker="*", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.title("TOP 5 Per Capita Income States - Sevices")
plt.plot(x_t5,regress_values,"r-")
plt.annotate(line_eq,(2.1,500000),fontsize=12,color="red")
plt.annotate(r2,(2.2,450000),fontsize=10,color="black")

plt.savefig(f"output_data/fig{fignum}.png")
fignum = fignum + 1
# Out:
# The slope of the line is:-287746.053
# The y-intercept is:987717.76
# The rvalue (Correlation coefficient) is:-0.234
# The pvalue is:0.26
# The standard error is:248937.68

# %% [markdown]
# ###Plotting Data gas price vs. durable goods (bottom 5 states)

# %%
x_b5 = gas_cost_Expend_botton5_df['Price per gallon'] # Gasoline Price 
y_b5_dg = gas_cost_Expend_botton5_df.iloc[:,2] #Durable Goods
y_b5_ndg = gas_cost_Expend_botton5_df.iloc[:,3] #NO Durable Goods
y_b5_s = gas_cost_Expend_botton5_df.iloc[:,4] # Services



#Linear Regression Durable Goods
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_b5,y_b5_dg)
r2 = (f"The r-squared is: {round(rvalue**2,4)}")
regress_values = x_b5 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The slope of the line is:{round(slope,3)}")
print(f"The y-intercept is:{round(intercept,3)}")
print(f"The rvalue (Correlation coefficient) is:{round(rvalue,3)}")
print(f"The pvalue is:{round(pvalue,3)}")
print(f"The standard error is:{round(stderr,3)}")

plt.scatter(x_b5,y_b5_dg, marker="o", facecolors="green", edgecolors="black",s=30, alpha=0.75)
plt.title("BOTTOM 5 Per Capita Income States - Durable Goods")
plt.plot(x_b5,regress_values,"r-")
plt.annotate(line_eq,(2.1,14000),fontsize=12,color="red")
plt.annotate(r2,(2.2,13000),fontsize=10,color="black")

plt.savefig(f"output_data/fig{fignum}.png")
fignum = fignum + 1
# Out:
# The slope of the line is:-5800.812
# The y-intercept is:24974.037
# The rvalue (Correlation coefficient) is:-0.227
# The pvalue is:0.276
# The standard error is:5196.294

# %% [markdown]
# ###Plotting Data gas price vs. nondurable goods (bottom 5 states)

# %%
#Linear Regression Non Durable Goods
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_b5,y_b5_ndg)
r2= (f"The r-squared is: {round(rvalue**2,4)}")
regress_values = x_b5 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The slope of the line is:{round(slope,3)}")
print(f"The y-intercept is:{round(intercept,3)}")
print(f"The rvalue (Correlation coefficient) is:{round(rvalue,3)}")
print(f"The pvalue is:{round(pvalue,3)}")
print(f"The standard error is:{round(stderr,3)}")

plt.scatter(x_b5,y_b5_ndg, marker="s", facecolors="brown", edgecolors="black",s=30, alpha=0.75)
plt.title("BOTTOM 5 Per Capita Income States - Non Durable Goods")
plt.plot(x_b5,regress_values,"r-")
plt.annotate(line_eq,(2.2,32000),fontsize=12,color="red")
plt.annotate(r2,(2.2,30000),fontsize=10,color="black")

plt.savefig(f"output_data/fig{fignum}.png")
fignum = fignum + 1
# Out:
# The slope of the line is:-10770.124
# The y-intercept is:50933.354
# The rvalue (Correlation coefficient) is:-0.184
# The pvalue is:0.378
# The standard error is:11993.615

# %% [markdown]
# ###Plotting Data gas price vs. services (bottom 5 states)

# %%
#Linear Regression Services
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_b5,y_b5_s)
r2 = (f"The r-squared is: {round(rvalue**2,4)}")
regress_values = x_b5 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The slope of the line is:{round(slope,3)}")
print(f"The y-intercept is:{round(intercept,3)}")
print(f"The rvalue (Correlation coefficient) is:{round(rvalue,3)}")
print(f"The pvalue is:{round(pvalue,3)}")
print(f"The standard error is:{round(stderr,3)}")

plt.scatter(x_b5,y_b5_s, marker="*", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.title("BOTTOM 5 Per Capita Income States - Sevices")
plt.plot(x_b5,regress_values,"r-")
plt.annotate(line_eq,(2.2,80000),fontsize=12,color="red")
plt.annotate(r2,(2.3,74000),fontsize=10,color="black")
plt.savefig(f"output_data/fig{fignum}.png")
fignum = fignum + 1
# Out:
# The slope of the line is:-22136.745
# The y-intercept is:119437.325
# The rvalue (Correlation coefficient) is:-0.163
# The pvalue is:0.436
# The standard error is:27906.932

# %%
###(Alternative way to plot)

#fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, figsize=(10,8))
#fig.suptitle('Price per gallon Vs Expenditures in Goods and Services')
#ax1.scatter(x,y_dg, marker="o", facecolors="green", edgecolors="black",s=30, alpha=0.75)
#ax1.set_title("Durable Goods")


#ax2.scatter(x,y_ndg, marker="s", facecolors="red", edgecolors="black",s=30, alpha=0.75)
#ax2.set_title("No Durable Goods")
#ax3.scatter(x,y_s, marker="*", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
#ax3.set_title("Services")
